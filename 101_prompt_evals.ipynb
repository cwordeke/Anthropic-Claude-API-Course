# %%
from dotenv import load_dotenv

load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences
    }

    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json

def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    # TODO - Grading
    score = 10

    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "Here's a Python function that extracts the bucket name from an AWS S3 bucket ARN:\n\n```python\ndef extract_bucket_name_from_arn(arn):\n    \"\"\"\n    Extracts the bucket name from an AWS S3 bucket ARN.\n    \n    Args:\n        arn (str): The S3 bucket ARN in format 'arn:aws:s3:::bucket-name'\n    \n    Returns:\n        str: The bucket name\n    \n    Raises:\n        ValueError: If the ARN format is invalid\n    \"\"\"\n    if not isinstance(arn, str):\n        raise ValueError(\"ARN must be a string\")\n    \n    if not arn:\n        raise ValueError(\"ARN cannot be empty\")\n    \n    # Split the ARN by colons\n    parts = arn.split(':')\n    \n    # Validate ARN format\n    if len(parts) != 6:\n        raise ValueError(\"Invalid ARN format. Expected format: 'arn:aws:s3:::bucket-name'\")\n    \n    if parts[0] != 'arn':\n        raise ValueError(\"ARN must start with 'arn'\")\n    \n    if parts[1] != 'aws':\n        raise ValueError(\"Invalid partition. Expected 'aws'\")\n    \n    if parts[2] != 's3':\n        raise ValueError(\"Invalid service. Expected 's3'\")\n    \n    if parts[3] != '':\n        raise ValueError(\"Region must be empty for S3 bucket ARNs\")\n    \n    if parts[4] != '':\n        raise ValueError(\"Account ID must be empty for S3 bucket ARNs\")\n    \n    # Extract bucket name (last part)\n    bucket_name = parts[5]\n    \n    if not bucket_name:\n        raise ValueError(\"Bucket name cannot be empty\")\n    \n    return bucket_name\n\n\n# Alternative simpler version with basic validation\ndef extract_bucket_name_simple(arn):\n    \"\"\"\n    Simple version to extract bucket name from S3 ARN.\n    \n    Args:\n        arn (str): The S3 bucket ARN\n    \n    Returns:\n        str: The bucket name\n    \"\"\"\n    if not arn or not isinstance(arn, str):\n        raise ValueError(\"Invalid ARN input\")\n    \n    if not arn.startswith('arn:aws:s3:::'):\n        raise ValueError(\"Invalid S3 bucket ARN format\")\n    \n    # Extract everything after 'arn:aws:s3:::'\n    bucket_name = arn[13:]  # len('arn:aws:s3:::') = 13\n    \n    if not bucket_name:\n        raise ValueError(\"Bucket name cannot be empty\")\n    \n    return bucket_name\n\n\n# Example usage and test cases\nif __name__ == \"__main__\":\n    # Test cases\n    test_arns = [\n        'arn:aws:s3:::my-bucket',\n        'arn:aws:s3:::my-test-bucket-123',\n        'arn:aws:s3:::example.bucket.name'\n    ]\n    \n    print(\"Testing with detailed validation:\")\n    for arn in test_arns:\n        try:\n            bucket_name = extract_bucket_name_from_arn(arn)\n            print(f\"ARN: {arn}\")\n            print(f\"Bucket Name: {bucket_name}\")\n            print(\"-\" * 40)\n        except ValueError as e:\n            print(f\"Error: {e}\")\n    \n    print(\"\\nTesting with simple version:\")\n    for arn in test_arns:\n        try:\n            bucket_name = extract_bucket_name_simple(arn)\n            print(f\"ARN: {arn} -> Bucket: {bucket_name}\")\n        except ValueError as e:\n            print(f\"Error: {e}\")\n    \n    # Test error cases\n    print(\"\\nTesting error cases:\")\n    error_test_cases = [\n        '',\n        'invalid-arn',\n        'arn:aws:s3:::',\n        'arn:aws:ec2:::bucket-name',\n        None\n    ]\n    ",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS S3 bucket ARN as input and extracts just the bucket name from it. The function should handle ARNs in the format 'arn:aws:s3:::bucket-name' and return only the bucket name portion."
#     },
#     "score": 10
#   },
#   {
#     "output": "Here's a JSON object that defines an AWS IAM policy for read-only access to the specific S3 bucket 'company-data-bucket':\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\",\n        \"s3:ListBucket\"\n      ],\n      \"Resource\": [\n        \"arn:aws:s3:::company-data-bucket\",\n        \"arn:aws:s3:::company-data-bucket/*\"\n      ]\n    }\n  ]\n}\n```\n\n**Explanation of the policy components:**\n\n- **Version**: `\"2012-10-17\"` - The current IAM policy language version\n- **Statement**: Contains the policy permissions\n  - **Effect**: `\"Allow\"` - Grants the specified permissions\n  - **Action**: Includes three read-only S3 actions:\n    - `s3:GetObject` - Allows downloading/reading objects from the bucket\n    - `s3:GetObjectVersion` - Allows reading specific versions of objects (for versioned buckets)\n    - `s3:ListBucket` - Allows listing the contents of the bucket\n  - **Resource**: Specifies two ARN patterns:\n    - `arn:aws:s3:::company-data-bucket` - The bucket itself (needed for ListBucket)\n    - `arn:aws:s3:::company-data-bucket/*` - All objects within the bucket (needed for GetObject actions)\n\nThis policy provides comprehensive read-only access to the specified bucket while preventing any write, delete, or administrative operations.",
#     "test_case": {
#       "task": "Create a JSON object that defines an AWS IAM policy allowing read-only access to a specific S3 bucket named 'company-data-bucket'. The policy should include the necessary Version, Statement with Effect, Action, and Resource fields."
#     },
#     "score": 10
#   },
#   {
#     "output": "Here's a regular expression that matches valid AWS EC2 instance IDs:\n\n```regex\n^i-[0-9a-f]{8}([0-9a-f]{9})?$\n```\n\nLet me break this down:\n\n- `^` - Start of string anchor\n- `i-` - Literal characters \"i-\"\n- `[0-9a-f]{8}` - Exactly 8 hexadecimal characters (0-9 and a-f)\n- `([0-9a-f]{9})?` - Optional group of exactly 9 more hexadecimal characters\n- `$` - End of string anchor\n\nThis pattern works because:\n- Old format: `i-` + 8 hex chars = matches the first part\n- New format: `i-` + 8 hex chars + 9 hex chars = matches both parts (total 17 hex chars)\n\n## Alternative approaches:\n\n**Using alternation (more explicit):**\n```regex\n^i-([0-9a-f]{8}|[0-9a-f]{17})$\n```\n\n**Case-insensitive version (if uppercase hex is allowed):**\n```regex\n^i-[0-9a-fA-F]{8}([0-9a-fA-F]{9})?$\n```\n\n## Example matches:\n- `i-1234abcd` \u2713 (old format)\n- `i-1234abcd987654321` \u2713 (new format)\n- `i-abcdef12` \u2713 (old format)\n- `i-0123456789abcdef0` \u2713 (new format)\n\n## Example non-matches:\n- `i-123` \u2717 (too short)\n- `i-1234abcdx` \u2717 (invalid character)\n- `ec2-123456` \u2717 (wrong prefix)\n\nThe first regex `^i-[0-9a-f]{8}([0-9a-f]{9})?$` is the most concise and efficient solution.",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs. Instance IDs follow the pattern of starting with 'i-' followed by either 8 hexadecimal characters (old format) or 17 hexadecimal characters (new format)."
#     },
#     "score": 10
#   }
# ]
